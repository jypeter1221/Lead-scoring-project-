# %% [markdown]
# # Employee Wellness Prediction

# %% [markdown]
# ## Importing Neccesary libararey

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Import The Dataset

# %%
df = pd.read_csv(r'C:\Users\DELL\Desktop\employee_train.CSV')

# %%
df
# Out:
#       S.No        Timestamp  Age  Gender         Country state self_employed  \
# 0        1  8/27/2014 11:29   37  Female   United States    IL           NaN
# 1        2  8/27/2014 11:29   44       M   United States    IN           NaN
# 2        3  8/27/2014 11:29   32    Male          Canada   NaN           NaN
# 3        4  8/27/2014 11:29   31    Male  United Kingdom   NaN           NaN
# 4        5  8/27/2014 11:30   31    Male   United States    TX           NaN
# ...    ...              ...  ...     ...             ...   ...           ...
# 1043  1044  8/29/2014 11:20   26    Male   United States    WA            No
# 1044  1045  8/29/2014 11:22   29       f  United Kingdom   NaN            No
# 1045  1046  8/29/2014 11:23   26  Female          Canada   NaN            No
# 1046  1047  8/29/2014 11:24   33    Malr           Italy   NaN            No
# 1047  1048  8/29/2014 11:25   28    Male          Brazil   NaN            No
#
# ...

# %% [markdown]
# # Data Inspection

# %%
# check Row and Bottom 
df.head(10)
# Out:
#    S.No        Timestamp  Age  Gender         Country state self_employed  \
# 0     1  8/27/2014 11:29   37  Female   United States    IL           NaN
# 1     2  8/27/2014 11:29   44       M   United States    IN           NaN
# 2     3  8/27/2014 11:29   32    Male          Canada   NaN           NaN
# 3     4  8/27/2014 11:29   31    Male  United Kingdom   NaN           NaN
# 4     5  8/27/2014 11:30   31    Male   United States    TX           NaN
# 5     6  8/27/2014 11:31   33    Male   United States    TN           NaN
# 6     7  8/27/2014 11:31   35  Female   United States    MI           NaN
# 7     8  8/27/2014 11:32   39       M          Canada   NaN           NaN
# 8     9  8/27/2014 11:32   42  Female   United States    IL           NaN
# 9    10  8/27/2014 11:32   23    Male          Canada   NaN           NaN
#
#   family_history treatment work_interfere  ...               leave  \
# 0             No       Yes          Often  ...       Somewhat easy
# ...

# %%
df.tail(10)
# Out:
#       S.No        Timestamp  Age  Gender         Country state self_employed  \
# 1038  1039  8/29/2014 11:11   34  Female   United States    CA            No
# 1039  1040  8/29/2014 11:12   35    Male   United States    OR            No
# 1040  1041  8/29/2014 11:19   28  female   United States    OH            No
# 1041  1042  8/29/2014 11:20   33    Male   United States    NY            No
# 1042  1043  8/29/2014 11:20   40       M   United States    WI            No
# 1043  1044  8/29/2014 11:20   26    Male   United States    WA            No
# 1044  1045  8/29/2014 11:22   29       f  United Kingdom   NaN            No
# 1045  1046  8/29/2014 11:23   26  Female          Canada   NaN            No
# 1046  1047  8/29/2014 11:24   33    Malr           Italy   NaN            No
# 1047  1048  8/29/2014 11:25   28    Male          Brazil   NaN            No
#
#      family_history treatment work_interfere  ...          leave  \
# ...

# %% [markdown]
# #### check the total number of row and shape also columns (length,shape,columns)

# %%
len(df)
# Out:
# 1048

# %%
df.shape
# Out:
# (1048, 28)

# %%
df.columns
# Out:
# Index(['S.No', 'Timestamp', 'Age', 'Gender', 'Country', 'state',
#        'self_employed', 'family_history', 'treatment', 'work_interfere',
#        'no_employees', 'remote_work', 'tech_company', 'benefits',
#        'care_options', 'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %% [markdown]
# #### Check the null values and datatypes(info)

# %%
#ckeck the null values
df.isnull()
# Out:
#        S.No  Timestamp    Age  Gender  Country  state  self_employed  \
# 0     False      False  False   False    False  False           True
# 1     False      False  False   False    False  False           True
# 2     False      False  False   False    False   True           True
# 3     False      False  False   False    False   True           True
# 4     False      False  False   False    False  False           True
# ...     ...        ...    ...     ...      ...    ...            ...
# 1043  False      False  False   False    False  False          False
# 1044  False      False  False   False    False   True          False
# 1045  False      False  False   False    False   True          False
# 1046  False      False  False   False    False   True          False
# 1047  False      False  False   False    False   True          False
#
#       family_history  treatment  work_interfere  ...  leave  \
# 0              False      False           False  ...  False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   S.No                       1048 non-null   int64
#  1   Timestamp                  1048 non-null   object
#  2   Age                        1048 non-null   int64
#  3   Gender                     1048 non-null   object
#  4   Country                    1048 non-null   object
#  5   state                      636 non-null    object
#  6   self_employed              1030 non-null   object
#  7   family_history             1048 non-null   object
#  8   treatment                  1048 non-null   object
#  9   work_interfere             812 non-null    object
#  10  no_employees               1048 non-null   object
#  11  remote_work                1048 non-null   object
#  12  tech_company               1048 non-null   object
# ...

# %% [markdown]
# ## check the describe statistics

# %%
df.describe()
# Out:
#               S.No           Age
# count  1048.000000  1.048000e+03
# mean    524.500000  9.541988e+07
# std     302.675844  3.089010e+09
# min       1.000000 -1.726000e+03
# 25%     262.750000  2.700000e+01
# 50%     524.500000  3.100000e+01
# 75%     786.250000  3.600000e+01
# max    1048.000000  1.000000e+11

# %% [markdown]
# # Data Preparartion (Transfromation)

# %%
# ckeck the missing values
df.isnull().sum()
# Out:
# S.No                           0
# Timestamp                      0
# Age                            0
# Gender                         0
# Country                        0
# state                        412
# self_employed                 18
# family_history                 0
# treatment                      0
# work_interfere               236
# no_employees                   0
# remote_work                    0
# tech_company                   0
# benefits                      13
# care_options                   0
# wellness_program               4
# seek_help                      0
# anonymity                      0
# leave                          4
# mental_health_consequence      0
# phys_health_consequence        0
# coworkers                      0
# supervisor                     0
# mental_health_interview        0
# phys_health_interview          0
# mental_vs_physical             0
# obs_consequence                0
# comments                     916
# dtype: int64

# %%
# check the missing values in percentage
df.isnull().sum()/(len(df))*100
# Out:
# S.No                          0.000000
# Timestamp                     0.000000
# Age                           0.000000
# Gender                        0.000000
# Country                       0.000000
# state                        39.312977
# self_employed                 1.717557
# family_history                0.000000
# treatment                     0.000000
# work_interfere               22.519084
# no_employees                  0.000000
# remote_work                   0.000000
# tech_company                  0.000000
# benefits                      1.240458
# care_options                  0.000000
# wellness_program              0.381679
# seek_help                     0.000000
# anonymity                     0.000000
# leave                         0.381679
# mental_health_consequence     0.000000
# phys_health_consequence       0.000000
# coworkers                     0.000000
# supervisor                    0.000000
# mental_health_interview       0.000000
# ...

# %%
df['comments'].value_counts()
# Out:
# comments
# * Small family business - YMMV.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 5
# ...

# %%
df.select_dtypes(include = 'object').columns
# Out:
# Index(['Timestamp', 'Gender', 'Country', 'state', 'self_employed',
#        'family_history', 'treatment', 'work_interfere', 'no_employees',
#        'remote_work', 'tech_company', 'benefits', 'care_options',
#        'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %%
# Finding All values with distinct counts
for columns in df.columns:
    if(df[columns].dtype == 'object'):
        print(columns + " " + str(len(df[columns].unique())))
# Out:
# Timestamp 679
# Gender 45
# Country 42
# state 46
# self_employed 3
# family_history 2
# treatment 2
# work_interfere 5
# no_employees 6
# remote_work 2
# tech_company 2
# benefits 4
# care_options 3
# wellness_program 4
# seek_help 3
# anonymity 3
# leave 6
# mental_health_consequence 3
# phys_health_consequence 3
# coworkers 3
# supervisor 3
# mental_health_interview 3
# phys_health_interview 3
# mental_vs_physical 3
# obs_consequence 2
# comments 129

# %% [markdown]
# # Binary Categorical (2 unique value)

# %%
df['family_history'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        No
# 1        No
# 2        No
# 3       Yes
# 4        No
#        ...
# 1043     No
# 1044     No
# 1045    Yes
# 1046    Yes
# 1047    Yes
# Name: family_history, Length: 1048, dtype: object>

# %%
df['treatment'].value_counts()
# Out:
# treatment
# No     536
# Yes    512
# Name: count, dtype: int64

# %%
df['remote_work'].value_counts()
# Out:
# remote_work
# No     733
# Yes    315
# Name: count, dtype: int64

# %%
df['tech_company'].value_counts()
# Out:
# tech_company
# Yes    870
# No     178
# Name: count, dtype: int64

# %%
df['family_history'] = df['family_history'].replace('Yes',1)

# %%
df['family_history'] = df['family_history'].replace('No',0)

# %%
df['treatment'] = df['treatment'].replace('Yes',1)

# %%
df['treatment'] = df['treatment'].replace('No',0)

# %%
df['remote_work'] = df['remote_work'].replace('Yes',1)

# %%
df['remote_work'] = df['remote_work'].replace('No',0)

# %%
df['tech_company'] = df['tech_company'].replace('Yes',1)

# %%
df['tech_company'] = df['tech_company'].replace('No',0)

# %%
df['obs_consequence'] = df['obs_consequence'].replace('Yes',1)

# %%
df['obs_consequence'] = df['obs_consequence'].replace('No',0)

# %%
# ckeck the datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   S.No                       1048 non-null   int64
#  1   Timestamp                  1048 non-null   object
#  2   Age                        1048 non-null   int64
#  3   Gender                     1048 non-null   object
#  4   Country                    1048 non-null   object
#  5   state                      636 non-null    object
#  6   self_employed              1030 non-null   object
#  7   family_history             1048 non-null   int64
#  8   treatment                  1048 non-null   int64
#  9   work_interfere             812 non-null    object
#  10  no_employees               1048 non-null   object
#  11  remote_work                1048 non-null   int64
#  12  tech_company               1048 non-null   int64
# ...

# %%
# Finding All values with distinct counts
for columns in df.columns:
    if(df[columns].dtype == 'object'):
        print(columns + " " + str(len(df[columns].unique())))
# Out:
# Timestamp 679
# Gender 45
# Country 42
# state 46
# self_employed 3
# work_interfere 5
# no_employees 6
# benefits 4
# care_options 3
# wellness_program 4
# seek_help 3
# anonymity 3
# leave 6
# mental_health_consequence 3
# phys_health_consequence 3
# coworkers 3
# supervisor 3
# mental_health_interview 3
# phys_health_interview 3
# mental_vs_physical 3
# comments 129

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male                        518
# male                        162
# M                           100
# Female                       99
# female                       48
# F                            33
# m                            30
# f                            13
# Make                          4
# Female                        2
# Cis Male                      2
# Woman                         2
# Female (trans)                2
# Man                           2
# Male                          1
# Agender                       1
# cis-female/femme              1
# Guy (-ish) ^_^                1
# male leaning androgynous      1
# A little about you            1
# Mail                          1
# Female (cis)                  1
# msle                          1
# Neuter                        1
# Androgyne                     1
# queer                         1
# cis male                      1
# Trans woman                   1
# Nah                           1
# ...

# %%
# Handling 'Gender' Column (Manual Mapping)
gender_map = {
    'Male': 'Male', 'male': 'Male', 'M': 'Male', 'm': 'Male', 'Make': 'Male', 'Mal': 'Male', 'Mail': 'Male', 'msle': 'Male', 'Malr': 'Male',
    'Female': 'Female', 'female': 'Female', 'F': 'Female', 'f': 'Female', 'woman': 'Female', 'cis-female/femme': 'Female',
    'Cis Female': 'Female', 'Trans-female': 'Female', 'Female (trans)': 'Female', 'Female (cis)': 'Female',
    'Non-binary': 'Non-binary', 'Neuter': 'Non-binary', 'Agender': 'Non-binary', 'Genderqueer': 'Non-binary',
    'Androgyne': 'Non-binary', 'fluid': 'Non-binary', 'queer': 'Non-binary', 'Enby': 'Non-binary', 'All': 'Non-binary',
    'A little about you': 'Non-binary', 'Nah': 'Non-binary', 'Guy (-ish) ^_^': 'Non-binary'
}

# %%
df['Gender'] = df['Gender'].map(gender_map).fillna('Other')

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male          818
# Female        200
# Other          19
# Non-binary     11
# Name: count, dtype: int64

# %%
freq_encoding = df['Gender'].value_counts(normalize = True)
df['Gender'] = df['Gender'].map(freq_encoding)

# %%
df['work_interfere'].value_counts()
# Out:
# work_interfere
# Sometimes    386
# Never        178
# Rarely       144
# Often        104
# Name: count, dtype: int64

# %%
# fill missing (NaN) values in the "work_interfere" column with the string "Nill"
df['work_interfere'].fillna('Nill',inplace = True)

# %%
from sklearn.preprocessing import OrdinalEncoder

# Define the order of categories
categories = [['Never', 'Rarely', 'Sometimes', 'Often', 'Nill']]

# Initialize Encoder
encoder = OrdinalEncoder(categories=categories)

# Fit and Transform
df['work_interfere'] = encoder.fit_transform(df[['work_interfere']])

# %%
df['no_employees'].value_counts()
# Out:
# no_employees
# 25-Jun            245
# 26-100            238
# More than 1000    227
# 100-500           150
# 05-Jan            133
# 500-1000           55
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder


categories = [['05-Jan', '25-Jun', '26-100', '100-500', '500-1000', 'More than 1000']]

# Initialize and apply Ordinal Encoder
encoder = OrdinalEncoder(categories=categories)
df['no_employees'] = encoder.fit_transform(df[['no_employees']])

# %%
freq_encoding = df['benefits'].value_counts(normalize=True)
df['benefits'] = df['benefits'].map(freq_encoding)

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize Label Encoder
encoder = LabelEncoder()

# Apply Label Encoding
df['care_options'] = encoder.fit_transform(df['care_options'])

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize Label Encoder
encoder = LabelEncoder()

# Apply Label Encoding
df['wellness_program'] = encoder.fit_transform(df['wellness_program'])

# %%
from sklearn.preprocessing import OrdinalEncoder

categories = [['No', "Don't know", 'Yes']]  # Define meaningful order
encoder = OrdinalEncoder(categories=categories)
df['seek_help'] = encoder.fit_transform(df[['seek_help']])

# %%
from sklearn.preprocessing import OrdinalEncoder

categories = [['No', "Don't know", 'Yes']]  # Define meaningful order
encoder = OrdinalEncoder(categories=categories)
df['anonymity'] = encoder.fit_transform(df[['anonymity']])

# %%
from sklearn.preprocessing import OrdinalEncoder

# Define category order
categories = [['Very difficult', 'Somewhat difficult', "Don't know", 'Somewhat easy', 'Very easy']]

# Fill NaN values with a default category (e.g., "Don't know")
df['leave'] = df['leave'].fillna("Don't know")  # You can choose another default if needed

# Initialize and apply Ordinal Encoder
encoder = OrdinalEncoder(categories=categories)
df['leave'] = encoder.fit_transform(df[['leave']])

# %%
from sklearn.preprocessing import OrdinalEncoder

# Define order
categories = [['No', 'Maybe', 'Yes']]

# Initialize and apply encoder
encoder = OrdinalEncoder(categories=categories)
df['mental_health_consequence'] = encoder.fit_transform(df[['mental_health_consequence']])

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
df['coworkers'] = encoder.fit_transform(df['coworkers'])

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
df['supervisor'] = encoder.fit_transform(df['supervisor'])

# %%
from sklearn.preprocessing import OrdinalEncoder

categories = [['No', "Maybe", 'Yes']]  # Define meaningful order
encoder = OrdinalEncoder(categories=categories)
df['mental_health_interview'] = encoder.fit_transform(df[['mental_health_interview']])

# %%
from sklearn.preprocessing import OrdinalEncoder

categories = [['No', "Don't know", 'Yes']]  # Define meaningful order
encoder = OrdinalEncoder(categories=categories)
df['mental_vs_physical'] = encoder.fit_transform(df[['mental_vs_physical']])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   S.No                       1048 non-null   int64
#  1   Timestamp                  1048 non-null   object
#  2   Age                        1048 non-null   int64
#  3   Gender                     1048 non-null   float64
#  4   Country                    1048 non-null   object
#  5   state                      636 non-null    object
#  6   self_employed              1030 non-null   object
#  7   family_history             1048 non-null   int64
#  8   treatment                  1048 non-null   int64
#  9   work_interfere             1048 non-null   float64
#  10  no_employees               1048 non-null   float64
#  11  remote_work                1048 non-null   int64
#  12  tech_company               1048 non-null   int64
# ...

# %%
df['phys_health_interview'].value_counts()
# Out:
# phys_health_interview
# Maybe    461
# No       419
# Yes      168
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize Label Encoder
encoder = LabelEncoder()

# Apply Label Encoding
df['phys_health_interview'] = encoder.fit_transform(df['phys_health_interview'])

# %%
# Finding All values with distinct counts
for columns in df.columns:
    if(df[columns].dtype == 'object'):
        print(columns + " " + str(len(df[columns].unique())))
# Out:
# Timestamp 679
# Country 42
# state 46
# self_employed 3
# phys_health_consequence 3
# comments 129

# %%
df['self_employed'].value_counts()
# Out:
# self_employed
# No     906
# Yes    124
# Name: count, dtype: int64

# %%
from sklearn.utils import resample

# Separate majority and minority classes
df_majority = df[df['self_employed'] == "No"]
df_minority = df[df['self_employed'] == "Yes"]

# %%
# Upsample the minority class
df_minority_upsampled = resample(df_minority, 
                                 replace=True,  # Sample with replacement
                                 n_samples=len(df_majority),  # Match majority class
                                 random_state=42)  # Reproducibility

# %%
# Combine majority and upsampled minority classes
df_upsampled = pd.concat([df_majority, df_minority_upsampled])

# %%
# Shuffle dataset
df_upsampled = df_upsampled.sample(frac=1, random_state=42).reset_index(drop=True)

print(df_upsampled['self_employed'].value_counts())  # Check new balance
# Out:
# self_employed
# Yes    906
# No     906
# Name: count, dtype: int64

# %%
df['self_employed'] = df['self_employed'].replace('Yes',1)

# %%
df['self_employed'] = df['self_employed'].replace('No',0)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Country'] = le.fit_transform(df['Country'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   S.No                       1048 non-null   int64
#  1   Timestamp                  1048 non-null   object
#  2   Age                        1048 non-null   int64
#  3   Gender                     1048 non-null   float64
#  4   Country                    1048 non-null   int32
#  5   state                      636 non-null    object
#  6   self_employed              1030 non-null   float64
#  7   family_history             1048 non-null   int64
#  8   treatment                  1048 non-null   int64
#  9   work_interfere             1048 non-null   float64
#  10  no_employees               1048 non-null   float64
#  11  remote_work                1048 non-null   int64
#  12  tech_company               1048 non-null   int64
# ...

# %%
df1 = df.drop(['Timestamp', 'state', 'self_employed', 'phys_health_consequence', 'obs_consequence','comments'], axis=1)

# %%
df1
# Out:
#         S.No   Age    Gender  Country  family_history  treatment  \
# 0        1.0  37.0  0.190840     39.0             0.0        1.0
# 1        2.0  44.0  0.780534     39.0             0.0        0.0
# 2        3.0  32.0  0.780534      7.0             0.0        0.0
# 3        4.0  31.0  0.780534     38.0             1.0        1.0
# 4        5.0  31.0  0.780534     39.0             0.0        0.0
# ...      ...   ...       ...      ...             ...        ...
# 1043  1044.0  26.0  0.780534     39.0             0.0        1.0
# 1044  1045.0  29.0  0.190840     38.0             0.0        1.0
# 1045  1046.0  26.0  0.190840      7.0             1.0        1.0
# 1046  1047.0  33.0  0.780534     19.0             1.0        1.0
# 1047  1048.0  28.0  0.780534      5.0             1.0        0.0
#
#       work_interfere  no_employees  remote_work  tech_company  ...  \
# 0                3.0           1.0          0.0           1.0  ...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   S.No                       1048 non-null   float64
#  1   Age                        1048 non-null   float64
#  2   Gender                     1048 non-null   float64
#  3   Country                    1048 non-null   float64
#  4   family_history             1048 non-null   float64
#  5   treatment                  1048 non-null   float64
#  6   work_interfere             1048 non-null   float64
#  7   no_employees               1048 non-null   float64
#  8   remote_work                1048 non-null   float64
#  9   tech_company               1048 non-null   float64
#  10  benefits                   1048 non-null   float64
#  11  care_options               1048 non-null   float64
#  12  wellness_program           1048 non-null   float64
# ...

# %%
## For numerical columns → Use mean/median

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')  # or 'median'
df_numeric = df.select_dtypes(include=['number'])  # Select only numeric columns
df[df_numeric.columns] = imputer.fit_transform(df_numeric)

# %%
## For categorical columns → Use most frequent value (mode)

# %%
imputer = SimpleImputer(strategy='most_frequent')
df_categorical = df.select_dtypes(include=['object'])  # Select categorical columns
df[df_categorical.columns] = imputer.fit_transform(df_categorical)

# %% [markdown]
# # Train_test_split

# %%
X = df1.drop('treatment',axis=1)

# %%
y = df1[['treatment']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.30, random_state=42)

# %%
X_train
# Out:
#         S.No   Age    Gender  Country  family_history  work_interfere  \
# 281    282.0  27.0  0.780534     28.0             0.0             0.0
# 266    267.0  41.0  0.780534     39.0             0.0             2.0
# 497    498.0  25.0  0.190840     39.0             1.0             3.0
# 807    808.0  36.0  0.190840     39.0             1.0             4.0
# 835    836.0  44.0  0.780534     38.0             1.0             2.0
# ...      ...   ...       ...      ...             ...             ...
# 330    331.0  24.0  0.780534     39.0             0.0             4.0
# 466    467.0  57.0  0.780534     39.0             1.0             1.0
# 121    122.0  25.0  0.780534     39.0             0.0             4.0
# 1044  1045.0  29.0  0.190840     38.0             0.0             3.0
# 860    861.0  32.0  0.780534     38.0             1.0             1.0
#
#       no_employees  remote_work  tech_company  benefits  ...  \
# 281            1.0          0.0           1.0  0.295652  ...
# ...

# %%
 X_test
# Out:
#         S.No   Age    Gender  Country  family_history  work_interfere  \
# 352    353.0  30.0  0.780534     38.0             0.0             0.0
# 984    985.0  27.0  0.780534      7.0             0.0             0.0
# 876    877.0  31.0  0.780534     39.0             0.0             4.0
# 982    983.0  34.0  0.190840     38.0             1.0             3.0
# 31      32.0  31.0  0.780534     39.0             1.0             1.0
# ...      ...   ...       ...      ...             ...             ...
# 97      98.0  31.0  0.780534     22.0             1.0             2.0
# 830    831.0  29.0  0.780534     39.0             1.0             2.0
# 1022  1023.0  32.0  0.780534     39.0             0.0             0.0
# 423    424.0  32.0  0.780534     38.0             1.0             2.0
# 932    933.0  43.0  0.018130     39.0             0.0             2.0
#
#       no_employees  remote_work  tech_company  benefits  ...  \
# 352            1.0          0.0           1.0  0.295652  ...
# ...

# %%
y_train
# Out:
#       treatment
# 281         0.0
# 266         1.0
# 497         1.0
# 807         0.0
# 835         1.0
# ...         ...
# 330         0.0
# 466         1.0
# 121         0.0
# 1044        1.0
# 860         1.0
#
# [733 rows x 1 columns]

# %%
y_test
# Out:
#       treatment
# 352         0.0
# 984         0.0
# 876         0.0
# 982         1.0
# 31          0.0
# ...         ...
# 97          1.0
# 830         0.0
# 1022        0.0
# 423         1.0
# 932         1.0
#
# [315 rows x 1 columns]

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %% [markdown]
# ## Scale all 4 Components--> train and test ( 2 each)

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.fit_transform(X_test)

# %%
y_train = scaler.fit_transform(y_train)

# %%
y_test = scaler.fit_transform(y_test)

# %%
from sklearn.ensemble import HistGradientBoostingClassifier

model = HistGradientBoostingClassifier()
model.fit(X_train, y_train)
# Out:
# HistGradientBoostingClassifier()

# %% [markdown]
# # Start with LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg = LogisticRegression()

# %%
lg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lg.predict(X_test)

# %% [markdown]
# ### Choose Right metrics , for Regression metric are different than Classification ( very different in Clustering)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %% [markdown]
# ### Compare between y_test, and y_pred and evaulate final score

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.69      0.68       158
#          1.0       0.68      0.67      0.68       157
#
#     accuracy                           0.68       315
#    macro avg       0.68      0.68      0.68       315
# weighted avg       0.68      0.68      0.68       315

# %% [markdown]
# ## Modelling with SVM Classifier

# %%
# modelling with svm slassifier
from sklearn.svm import SVC

# %%
svc = SVC()

# %%
svc.fit(X_train,y_train)
# Out:
# SVC()

# %%
# Make predition 
y_pred = svc.predict(X_test)

# %%
#classification metrics
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.69      0.70       158
#          1.0       0.70      0.71      0.70       157
#
#     accuracy                           0.70       315
#    macro avg       0.70      0.70      0.70       315
# weighted avg       0.70      0.70      0.70       315

# %% [markdown]
# # Reapeat all with new Feature, i.e. Different Feature selection mechanism

# %%
# Modelling with Decision Tree Classifier 

from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dt = dt.predict(X_test)

# %%
print(classification_report(y_test,y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.77      0.76       158
#          1.0       0.76      0.75      0.76       157
#
#     accuracy                           0.76       315
#    macro avg       0.76      0.76      0.76       315
# weighted avg       0.76      0.76      0.76       315

# %% [markdown]
# # Fitting KNN Model with K = 1

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=11) # if we dont assign the parameter n_nighbours=11 here,then by the deaful 
## value is given as 5.

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=11)

# %%
y_pred_knn = knn.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.69      0.70       158
#          1.0       0.70      0.71      0.70       157
#
#     accuracy                           0.70       315
#    macro avg       0.70      0.70      0.70       315
# weighted avg       0.70      0.70      0.70       315
